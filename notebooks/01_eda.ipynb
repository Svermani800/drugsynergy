# %% [markdown]
# Inspect the actual CSV and the cleaning audit.
#
# Extreme scores require source investigation before scientific interpretation.

# %%
from pathlib import Path
import os
if Path.cwd().name == "notebooks": os.chdir("..")

# %%
from src.data import load_clean
df, audit = load_clean("data/raw/drugcombs_scored.csv")
audit

# %%
df.synergy.describe(percentiles=[.01,.5,.99])
